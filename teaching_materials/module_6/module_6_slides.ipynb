# %% [markdown]
# # Session 6: Web Scraping 1
# *Hjalte Fejerskov Boas*

# %% [markdown]
# # About me
#
# - PhD student in Economics at UCPH
#     - At the moment: working on a project about cryptocurrencies and taxation
# - Master and bachelor from UCPH
# - Had this course in 2017
# - Taught the course in 2022
# - Personal website: https://www.hjalteboas.com/

# %% [markdown]
# ## Recap
# In session 5 you briefly touched upon extracting data from the internet
# - You heard about HTTP requests: The computer's way to communicate with the website and underlying server
# - You learned about HTML: The language behind a website
# - You worked with APIs: A way to retrieve structured data from websites
#     - You learned how to send requests to an API and in return receive the desired data
#     - You learned how to deal with the JSON files that is usually how the data is sent

# %% [markdown]
# In the next three sessions we will build on your newly acquired skills
#
# You will learn how to extract data from websites when no API is available
#
# It will open up a whole new world of data possibilities!

# %% [markdown]
# ## Required readings
#
# - [Beautiful Soup: Build a Web Scraper With Python](https://realpython.com/beautiful-soup-web-scraper-python/)
#
# - [A Practical Introduction to Web Scraping in Python](https://realpython.com/python-web-scraping-practical-introduction/)
#
# - Shiab, Nael. 2015. [On the Ethics of Web Scraping and Data Journalism](http://gijn.org/2015/08/12/on-the-ethics-of-web-scraping-and-data-journalism/). Global Investigative Journalism Network.

# %% [markdown]
# ## Overview of Session 6
#
# Today, we will learn about interacting with websites and extracting their unstructured data (web scraping). In particular, we will cover:
# 1. Basics of web scraping:
#     - What is web scraping?
#     - How is a webpage built? How does a computer "see" a webpage?
#     - Ethical considerations
# 2. Mapping the URLs of the webpages you want to scrape:
#     - How can we systematically go through all the webpages and scrape their content?
#         - You will learn to exploit the pattern in the URLs
# 3. Connecting to a webpage:
#     - How do we extract the HTML code behind the webpage?
# 4. Good practices of web scraping
#     - Limit the rate of your calls to the webpage
#     - Logging
#     - Handle exceptions
# 5. Exploiting the webpage's own data requests to extract data easily
#     - Use the network panel in Chrome Developer Tools to locate the data

# %% [markdown]
# ## What is web scraping?
#
# Web scraping is the practice of extracting information from websites in an automated and structured way
#
# - The internet is the biggest source of information/data you can find! [90% of the data on the internet has been created since 2016](https://blog.microfocus.com/how-much-data-is-created-on-the-internet-each-day/)
# - Web scraping unlock this new world of data possibilities
# - The biggest limitation is your own imagination!

# %% [markdown]
# #### One note:
# - Learning how to web scrape may be frustrating in the beginning
#     - It is a new way of thinking data
#     - It requires technological knowledge
# - Keep working with it!
#     - I promise you; you will master it
#     - And the internet will never be the same again

# %% [markdown]
# ## How a human sees a webpage vs. how a computer sees it

# %% [markdown]
# ### [www.jobnet.dk](https://job.jobnet.dk/CV/FindWork?Offset=0&SortValue=BestMatch)
#
# How a human sees a webpage             |  How a computer sees a webpage
# :-------------------------:|:-------------------------:
# ![](https://drive.google.com/thumbnail?id=1cbrC303j-gQnXbXyTEQBPT2xH7kgz6Cy&sz=w1000)  |  ![](https://drive.google.com/thumbnail?id=1VFlfDcJHCzbtmkpr4kvXzGecrDE7KmLY&sz=w1000)

# %% [markdown]
# ## Ethical Considerations (rule of thumbs)
# 1. Fair use: Take only the stuff you need
# 2. Be careful with copyrighted material
# 3. If a regular user can’t access it, we shouldn’t try to get it: [That is considered hacking](https://www.dr.dk/nyheder/penge/gjorde-opmaerksom-paa-cpr-hul-nu-bliver-han-politianmeldt-hacking)
# 4. If monetizing on the data, be careful not to be in direct competition with whom you are taking the data from
# 5. LinkedIn case: [Scraping data on LinkedIn is legal](https://gizmodo.com/linkedin-scraping-data-legal-court-case-1848811335)
# 6. Don't hit it too fast: Essentially a DENIAL OF SERVICE attack (DOS); [Again considered hacking](https://www.dr.dk/nyheder/indland/folketingets-hjemmeside-ramt-af-hacker-angreb)

# %% [markdown]
# <img src="https://github.com/snorreralund/images/raw/master/Sk%C3%A6rmbillede%202017-08-03%2014.46.32.png"/>

# %% [markdown]
# ## The Web Scraping Recipe
#
# Three (main) steps in scraping:
# 1. **MAPPING (this session)**: Find URLs of the webpages containing the information you want.
# 2. **DOWNLOADING (this session)**: Download the HTML of the webpages.
# 3. **PARSING (session 7)**: Extract the information from the HTML.

# %% [markdown]
# ### What browser to use?
# - Lectures and exercises are solely based on Chrome as my browser --> I recommend you to use Chrome as well.
# - All browsers (Chrome, Firefox, Safari, Edge etc.) can be used to investigate the webpages like you will learn to do here
#     - The practice might differ a bit

# %%
import requests
import time
import tqdm
import pandas as pd
import os
import json

# %% [markdown]
# # Video 6.1: Mapping URLs and downloading webpage content

# %% [markdown]
# ## 1. Mapping: How do we find the relevant URLs

# %% [markdown]
# ### Navigating websites to collect links
#
# How can you automate the navigation of links?

# %% [markdown]
# ### Building URLs using a recognizable pattern
# A nice trick is to understand how URLs are constructed to communicate with a server
#
# This will allow us to navigate the page:
#
# * / is like folders on your computer.
# * ? entails the start of a query with parameters
# * = defines a variable: e.g. page=1000 or offset=100 or showNumber=20
# * & separates different parameters.
# * \+ is html for whitespace

# %% [markdown]
# Lets look at how [www.jobindex.dk](https://www.jobindex.dk/jobsoegning) does it:
# - We simply click around and take note at how the address line changes

# %% [markdown]
# #### We want to create the URLs for the first 5 pages
# Is there a pattern in the URL that we can exploit?

# %%
links = []
for page in range(1,6,1):
    url = f'https://www.jobindex.dk/jobsoegning?page={page}'
    links.append(url)

# %%
links
# Out:
# ['https://www.jobindex.dk/jobsoegning?page=1',
#  'https://www.jobindex.dk/jobsoegning?page=2',
#  'https://www.jobindex.dk/jobsoegning?page=3',
#  'https://www.jobindex.dk/jobsoegning?page=4',
#  'https://www.jobindex.dk/jobsoegning?page=5']

# %% [markdown]
# ## 2. Connect to the webpage and *download* its content

# %% [markdown]
# ### Here is how you connect to and download the HTML of a webpage

# %%
import requests
response = requests.get('https://www.jobindex.dk/jobsoegning?page=1')

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="da-DK">\n    \n<head>\n    <title>Ledige job | Jobindex</title>\n    <meta content="IE=edge" http-equiv="X-UA-Compatible">\n    <meta charset="UTF-8">\n\n    \n        <link rel="icon" href="/favicon.ico" sizes="any">\n        <link rel="icon" href="/icon.svg" type="image/svg+xml">\n        <link rel="apple-touch-icon" href="/apple-touch-icon.png">\n    <link rel="manifest" href="/manifest.webmanifest">\n\n    <link href="/res/bootstrap-multiselect/dist/css/bootstrap-multiselect.css?h=6a6b68a249811e054fa8d759452816a9248c0748" rel="stylesheet"><link href="/res/select2/dist/css/select2.min.css?h=a170ecdd58f00519741ed4b63abc064ef35db1a9" rel="stylesheet"><link href="/res/bootstrap-datepicker/dist/css/bootstrap-datepicker3.standalone.min.css?h=f02cbfe4614ade97b3e5823be92702ae7bd445cd" rel="stylesheet"><link href="/res/maplibre-gl/dist/maplibre-gl.css?h=0b7aecaa763c9b1b2cb3b2f908ae2456699cad67" rel="stylesheet"><link href="/res/font-awesome/css/font-awesome.css?h=ee906a8196d0fbd581c27a9d5615db4c250860f2" rel="stylesheet"><link href="/css/_scss/fonts/roboto.5ea080079207ad7dd581.css" rel="stylesheet"><link href="/css/_scss/fonts/frank_ruhl_libre.15701488e7249b2dbfe5.css" rel="stylesheet"><link href="/css/_scss/themes/jobindex.cf10eab771fcc3e82823.css" rel="stylesheet">\n\n    <meta content="text/html; charset=UTF-8" http-equiv="content-type"><meta content="da-DK" http-equiv="content-language">\n    <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"><meta content="none" name="msapplication-config"><meta content="#b41018" name="theme-color">\n\n\n\n    <script type="application/ld+json">\n        {"@context":"https:\\/\\/schema.org","@type":"WebSite","name":"Jobindex","url":"https:\\/\\/www.jobindex.dk\\/"}\n    </script>\n    <meta content="Jobindex" property="og:site_name">\n    \n    <meta content="https://www.jobindex.dk/jobsoegning" property="og:url">\n    \n    \n<link href="https://www.jobindex.dk/jobsoegning" rel="canonical">\n<link href="https://www.jobindex.dk/jobsoegning" hreflang="da" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?lang=en" hreflang="en" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning" hreflang="x-default" rel="alternate">\n\n    <link href="/jobsoegning.rss" rel="alternate nofollow" title="Alle ledige job" type="application/rss+xml">\n\n    <script>//<![CDATA[\n\n    window.JIX = window.JIX || {};\n    (function () {\n        \'use strict\';\n        if (window.JIX.CookieConsent) {\n            return;\n        }\n        \n        function required(cat) {\n            return ["necessary"].indexOf(cat) >= 0;\n        }\n        // In case an ad blocker rejects our real implementation, we\'ll just do nothing and leave people alone.\n        window.JIX.CookieConsent = {\n            hasConsent: function (cat) { return new Promise(function (resolve) { resolve(required(cat)) }); },\n            whenConsent: function (cat, f) { if (required(cat)) { f(); } },\n        };\n    })();\n\n//]]></script>\n    \n<script>//<![CDATA[\n\n    var Stash = {"common":{"companyuserid":null,"csrf_token":"1bcba7bd4d4cf90931b6e1a2aef160d806128f20","lang":"da","lang_available":["da","en"],"lang_native":"da","site":"jobdk","sitename":"Jobindex","sitename_genitive":"Jobindex\'","userid":null},"cookie_consent":{"categories":[{"key":"necessary","required":true,"title":"Nødvendige"},{"key":"statistics","required":false,"title":"Statistik"},{"key":"marketing","required":false,"title":"Markedsføring"}],"cookieOptions":{"domain":".jobindex.dk","maxAge":31536000,"name":"jix-consent","path":"\\/","secure":true},"currentVersion":1,"latestTermsVersion":203,"options":{"enableAutoOpen":true,"enableBox":true,"modalCss":[],"sandbox":false},"urls":{"logConsent":"\\/api\\/cookie-consent\\/v1\\/log"}},"jobagent\\/popup":{"formSelector":"#jobagent_form"},"jobsearch":{"form_options":{"api":{"find_company":"\\/jobagent\\/virksomhed"},"archive":{"maxd ...

# %% [markdown]
# #### Remember to tell who you are
# - Write your name and email in the header of the request you send to the webpage
# - Then the managers of the webpage will know you are not a malicious actor

# %%
response = requests.get('https://www.jobindex.dk/jobsoegning?page=1', headers={'name':'Hjalte Fejerskov Boas','email':'hfb@econ.ku.dk'})

# %% [markdown]
# ### We now want to download the content of all 5 links we made earlier

# %%
list_htmls = []
for url in links:
    response = requests.get(url)
    html = response.text
    list_htmls.append(html)

# %%
list_htmls
# Out:
# ['<!DOCTYPE html>\n<html lang="da-DK">\n    \n<head>\n    <title>Ledige job | Jobindex</title>\n    <meta content="IE=edge" http-equiv="X-UA-Compatible">\n    <meta charset="UTF-8">\n\n    \n        <link rel="icon" href="/favicon.ico" sizes="any">\n        <link rel="icon" href="/icon.svg" type="image/svg+xml">\n        <link rel="apple-touch-icon" href="/apple-touch-icon.png">\n    <link rel="manifest" href="/manifest.webmanifest">\n\n    <link href="/res/bootstrap-multiselect/dist/css/bootstrap-multiselect.css?h=6a6b68a249811e054fa8d759452816a9248c0748" rel="stylesheet"><link href="/res/select2/dist/css/select2.min.css?h=a170ecdd58f00519741ed4b63abc064ef35db1a9" rel="stylesheet"><link href="/res/bootstrap-datepicker/dist/css/bootstrap-datepicker3.standalone.min.css?h=f02cbfe4614ade97b3e5823be92702ae7bd445cd" rel="stylesheet"><link href="/res/maplibre-gl/dist/maplibre-gl.css?h=0b7aecaa763c9b1b2cb3b2f908ae2456699cad67" rel="stylesheet"><link href="/res/font-awesome/css/font-awesome.css?h=ee906a8196d0fbd581c27a9d5615db4c250860f2" rel="stylesheet"><link href="/css/_scss/fonts/roboto.5ea080079207ad7dd581.css" rel="stylesheet"><link href="/css/_scss/fonts/frank_ruhl_libre.15701488e7249b2dbfe5.css" rel="stylesheet"><link href="/css/_scss/themes/jobindex.cf10eab771fcc3e82823.css" rel="stylesheet">\n\n    <meta content="text/html; charset=UTF-8" http-equiv="content-type"><meta content="da-DK" http-equiv="content-language">\n    <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"><meta content="none" name="msapplication-config"><meta content="#b41018" name="theme-color">\n\n\n\n    <script type="application/ld+json">\n        {"@context":"https:\\/\\/schema.org","@type":"WebSite","name":"Jobindex","url":"https:\\/\\/www.jobindex.dk\\/"}\n    </script>\n    <meta content="Jobindex" property="og:site_name">\n    \n    <meta content="https://www.jobindex.dk/jobsoegning" property="og:url">\n    \n    \n<link href="https://www.jobindex.dk/jobsoegning" rel="canonical">\n<link href="https://www.jobindex.dk/jobsoegning" hreflang="da" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?lang=en" hreflang="en" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning" hreflang="x-default" rel="alternate">\n\n    <link href="/jobsoegning.rss" rel="alternate nofollow" title="Alle ledige job" type="application/rss+xml">\n\n    <script>//<![CDATA[\n\n    window.JIX = window.JIX || {};\n    (function () {\n        \'use strict\';\n        if (window.JIX.CookieConsent) {\n            return;\n        }\n        \n        function required(cat) {\n            return ["necessary"].indexOf(cat) >= 0;\n        }\n        // In case an ad blocker rejects our real implementation, we\'ll just do nothing and leave people alone.\n        window.JIX.CookieConsent = {\n            hasConsent: function (cat) { return new Promise(function (resolve) { resolve(required(cat)) }); },\n            whenConsent: function (cat, f) { if (required(cat)) { f(); } },\n        };\n    })();\n\n//]]></script>\n    \n<script>//<![CDATA[\n\n    var Stash = {"common":{"companyuserid":null,"csrf_token":"5b6ccf338f3985a87d67ca35ae716509166cb6cf","lang":"da","lang_available":["da","en"],"lang_native":"da","site":"jobdk","sitename":"Jobindex","sitename_genitive":"Jobindex\'","userid":null},"cookie_consent":{"categories":[{"key":"necessary","required":true,"title":"Nødvendige"},{"key":"statistics","required":false,"title":"Statistik"},{"key":"marketing","required":false,"title":"Markedsføring"}],"cookieOptions":{"domain":".jobindex.dk","maxAge":31536000,"name":"jix-consent","path":"\\/","secure":true},"currentVersion":1,"latestTermsVersion":203,"options":{"enableAutoOpen":true,"enableBox":true,"modalCss":[],"sandbox":false},"urls":{"logConsent":"\\/api\\/cookie-consent\\/v1\\/log"}},"jobagent\\/popup":{"formSelector":"#jobagent_form"},"jobsearch":{"form_options":{"api":{"find_company":"\\/jobagent\\/virksomhed"},"archive":{"max ...
#  '<!DOCTYPE html>\n<html lang="da-DK">\n    \n<head>\n    <title>Ledige job, side 2 ud af 732 | Jobindex</title>\n    <meta content="IE=edge" http-equiv="X-UA-Compatible">\n    <meta charset="UTF-8">\n\n    \n        <link rel="icon" href="/favicon.ico" sizes="any">\n        <link rel="icon" href="/icon.svg" type="image/svg+xml">\n        <link rel="apple-touch-icon" href="/apple-touch-icon.png">\n    <link rel="manifest" href="/manifest.webmanifest">\n\n    <link href="/res/bootstrap-multiselect/dist/css/bootstrap-multiselect.css?h=6a6b68a249811e054fa8d759452816a9248c0748" rel="stylesheet"><link href="/res/select2/dist/css/select2.min.css?h=a170ecdd58f00519741ed4b63abc064ef35db1a9" rel="stylesheet"><link href="/res/bootstrap-datepicker/dist/css/bootstrap-datepicker3.standalone.min.css?h=f02cbfe4614ade97b3e5823be92702ae7bd445cd" rel="stylesheet"><link href="/res/maplibre-gl/dist/maplibre-gl.css?h=0b7aecaa763c9b1b2cb3b2f908ae2456699cad67" rel="stylesheet"><link href="/res/font-awesome/css/font-awesome.css?h=ee906a8196d0fbd581c27a9d5615db4c250860f2" rel="stylesheet"><link href="/css/_scss/fonts/roboto.5ea080079207ad7dd581.css" rel="stylesheet"><link href="/css/_scss/fonts/frank_ruhl_libre.15701488e7249b2dbfe5.css" rel="stylesheet"><link href="/css/_scss/themes/jobindex.cf10eab771fcc3e82823.css" rel="stylesheet">\n\n    <meta content="text/html; charset=UTF-8" http-equiv="content-type"><meta content="da-DK" http-equiv="content-language">\n    <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"><meta content="none" name="msapplication-config"><meta content="#b41018" name="theme-color">\n\n\n\n    <script type="application/ld+json">\n        {"@context":"https:\\/\\/schema.org","@type":"WebSite","name":"Jobindex","url":"https:\\/\\/www.jobindex.dk\\/"}\n    </script>\n    <meta content="Jobindex" property="og:site_name">\n    \n    <meta content="https://www.jobindex.dk/jobsoegning?page=2" property="og:url">\n    \n    \n<link href="https://www.jobindex.dk/jobsoegning?page=2" rel="canonical">\n<link href="https://www.jobindex.dk/jobsoegning?page=2" hreflang="da" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?page=2&amp;lang=en" hreflang="en" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?page=2" hreflang="x-default" rel="alternate">\n\n    <link href="/jobsoegning.rss" rel="alternate nofollow" title="Alle ledige job" type="application/rss+xml">\n\n    <script>//<![CDATA[\n\n    window.JIX = window.JIX || {};\n    (function () {\n        \'use strict\';\n        if (window.JIX.CookieConsent) {\n            return;\n        }\n        \n        function required(cat) {\n            return ["necessary"].indexOf(cat) >= 0;\n        }\n        // In case an ad blocker rejects our real implementation, we\'ll just do nothing and leave people alone.\n        window.JIX.CookieConsent = {\n            hasConsent: function (cat) { return new Promise(function (resolve) { resolve(required(cat)) }); },\n            whenConsent: function (cat, f) { if (required(cat)) { f(); } },\n        };\n    })();\n\n//]]></script>\n    \n<script>//<![CDATA[\n\n    var Stash = {"common":{"companyuserid":null,"csrf_token":"6fcd4ded39a1321f91c885a7131374c10c89a0e2","lang":"da","lang_available":["da","en"],"lang_native":"da","site":"jobdk","sitename":"Jobindex","sitename_genitive":"Jobindex\'","userid":null},"cookie_consent":{"categories":[{"key":"necessary","required":true,"title":"Nødvendige"},{"key":"statistics","required":false,"title":"Statistik"},{"key":"marketing","required":false,"title":"Markedsføring"}],"cookieOptions":{"domain":".jobindex.dk","maxAge":31536000,"name":"jix-consent","path":"\\/","secure":true},"currentVersion":1,"latestTermsVersion":203,"options":{"enableAutoOpen":true,"enableBox":true,"modalCss":[],"sandbox":false},"urls":{"logConsent":"\\/api\\/cookie-consent\\/v1\\/log"}},"jobagent\\/popup":{"formSelector":"#jobagent_form"},"jobsearch":{"form_options":{"api":{" ...
#  '<!DOCTYPE html>\n<html lang="da-DK">\n    \n<head>\n    <title>Ledige job, side 3 ud af 732 | Jobindex</title>\n    <meta content="IE=edge" http-equiv="X-UA-Compatible">\n    <meta charset="UTF-8">\n\n    \n        <link rel="icon" href="/favicon.ico" sizes="any">\n        <link rel="icon" href="/icon.svg" type="image/svg+xml">\n        <link rel="apple-touch-icon" href="/apple-touch-icon.png">\n    <link rel="manifest" href="/manifest.webmanifest">\n\n    <link href="/res/bootstrap-multiselect/dist/css/bootstrap-multiselect.css?h=6a6b68a249811e054fa8d759452816a9248c0748" rel="stylesheet"><link href="/res/select2/dist/css/select2.min.css?h=a170ecdd58f00519741ed4b63abc064ef35db1a9" rel="stylesheet"><link href="/res/bootstrap-datepicker/dist/css/bootstrap-datepicker3.standalone.min.css?h=f02cbfe4614ade97b3e5823be92702ae7bd445cd" rel="stylesheet"><link href="/res/maplibre-gl/dist/maplibre-gl.css?h=0b7aecaa763c9b1b2cb3b2f908ae2456699cad67" rel="stylesheet"><link href="/res/font-awesome/css/font-awesome.css?h=ee906a8196d0fbd581c27a9d5615db4c250860f2" rel="stylesheet"><link href="/css/_scss/fonts/roboto.5ea080079207ad7dd581.css" rel="stylesheet"><link href="/css/_scss/fonts/frank_ruhl_libre.15701488e7249b2dbfe5.css" rel="stylesheet"><link href="/css/_scss/themes/jobindex.cf10eab771fcc3e82823.css" rel="stylesheet">\n\n    <meta content="text/html; charset=UTF-8" http-equiv="content-type"><meta content="da-DK" http-equiv="content-language">\n    <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"><meta content="none" name="msapplication-config"><meta content="#b41018" name="theme-color">\n\n\n\n    <script type="application/ld+json">\n        {"@context":"https:\\/\\/schema.org","@type":"WebSite","name":"Jobindex","url":"https:\\/\\/www.jobindex.dk\\/"}\n    </script>\n    <meta content="Jobindex" property="og:site_name">\n    \n    <meta content="https://www.jobindex.dk/jobsoegning?page=3" property="og:url">\n    \n    \n<link href="https://www.jobindex.dk/jobsoegning?page=3" rel="canonical">\n<link href="https://www.jobindex.dk/jobsoegning?page=3" hreflang="da" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?page=3&amp;lang=en" hreflang="en" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?page=3" hreflang="x-default" rel="alternate">\n\n    <link href="/jobsoegning.rss" rel="alternate nofollow" title="Alle ledige job" type="application/rss+xml">\n\n    <script>//<![CDATA[\n\n    window.JIX = window.JIX || {};\n    (function () {\n        \'use strict\';\n        if (window.JIX.CookieConsent) {\n            return;\n        }\n        \n        function required(cat) {\n            return ["necessary"].indexOf(cat) >= 0;\n        }\n        // In case an ad blocker rejects our real implementation, we\'ll just do nothing and leave people alone.\n        window.JIX.CookieConsent = {\n            hasConsent: function (cat) { return new Promise(function (resolve) { resolve(required(cat)) }); },\n            whenConsent: function (cat, f) { if (required(cat)) { f(); } },\n        };\n    })();\n\n//]]></script>\n    \n<script>//<![CDATA[\n\n    var Stash = {"common":{"companyuserid":null,"csrf_token":"382bbaa3c3bfd1331bc1557868a7c58efadc68a8","lang":"da","lang_available":["da","en"],"lang_native":"da","site":"jobdk","sitename":"Jobindex","sitename_genitive":"Jobindex\'","userid":null},"cookie_consent":{"categories":[{"key":"necessary","required":true,"title":"Nødvendige"},{"key":"statistics","required":false,"title":"Statistik"},{"key":"marketing","required":false,"title":"Markedsføring"}],"cookieOptions":{"domain":".jobindex.dk","maxAge":31536000,"name":"jix-consent","path":"\\/","secure":true},"currentVersion":1,"latestTermsVersion":203,"options":{"enableAutoOpen":true,"enableBox":true,"modalCss":[],"sandbox":false},"urls":{"logConsent":"\\/api\\/cookie-consent\\/v1\\/log"}},"jobagent\\/popup":{"formSelector":"#jobagent_form"},"jobsearch":{"form_options":{"api":{" ...
#  '<!DOCTYPE html>\n<html lang="da-DK">\n    \n<head>\n    <title>Ledige job, side 4 ud af 732 | Jobindex</title>\n    <meta content="IE=edge" http-equiv="X-UA-Compatible">\n    <meta charset="UTF-8">\n\n    \n        <link rel="icon" href="/favicon.ico" sizes="any">\n        <link rel="icon" href="/icon.svg" type="image/svg+xml">\n        <link rel="apple-touch-icon" href="/apple-touch-icon.png">\n    <link rel="manifest" href="/manifest.webmanifest">\n\n    <link href="/res/bootstrap-multiselect/dist/css/bootstrap-multiselect.css?h=6a6b68a249811e054fa8d759452816a9248c0748" rel="stylesheet"><link href="/res/select2/dist/css/select2.min.css?h=a170ecdd58f00519741ed4b63abc064ef35db1a9" rel="stylesheet"><link href="/res/bootstrap-datepicker/dist/css/bootstrap-datepicker3.standalone.min.css?h=f02cbfe4614ade97b3e5823be92702ae7bd445cd" rel="stylesheet"><link href="/res/maplibre-gl/dist/maplibre-gl.css?h=0b7aecaa763c9b1b2cb3b2f908ae2456699cad67" rel="stylesheet"><link href="/res/font-awesome/css/font-awesome.css?h=ee906a8196d0fbd581c27a9d5615db4c250860f2" rel="stylesheet"><link href="/css/_scss/fonts/roboto.5ea080079207ad7dd581.css" rel="stylesheet"><link href="/css/_scss/fonts/frank_ruhl_libre.15701488e7249b2dbfe5.css" rel="stylesheet"><link href="/css/_scss/themes/jobindex.cf10eab771fcc3e82823.css" rel="stylesheet">\n\n    <meta content="text/html; charset=UTF-8" http-equiv="content-type"><meta content="da-DK" http-equiv="content-language">\n    <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"><meta content="none" name="msapplication-config"><meta content="#b41018" name="theme-color">\n\n\n\n    <script type="application/ld+json">\n        {"@context":"https:\\/\\/schema.org","@type":"WebSite","name":"Jobindex","url":"https:\\/\\/www.jobindex.dk\\/"}\n    </script>\n    <meta content="Jobindex" property="og:site_name">\n    \n    <meta content="https://www.jobindex.dk/jobsoegning?page=4" property="og:url">\n    \n    \n<link href="https://www.jobindex.dk/jobsoegning?page=4" rel="canonical">\n<link href="https://www.jobindex.dk/jobsoegning?page=4" hreflang="da" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?page=4&amp;lang=en" hreflang="en" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?page=4" hreflang="x-default" rel="alternate">\n\n    <link href="/jobsoegning.rss" rel="alternate nofollow" title="Alle ledige job" type="application/rss+xml">\n\n    <script>//<![CDATA[\n\n    window.JIX = window.JIX || {};\n    (function () {\n        \'use strict\';\n        if (window.JIX.CookieConsent) {\n            return;\n        }\n        \n        function required(cat) {\n            return ["necessary"].indexOf(cat) >= 0;\n        }\n        // In case an ad blocker rejects our real implementation, we\'ll just do nothing and leave people alone.\n        window.JIX.CookieConsent = {\n            hasConsent: function (cat) { return new Promise(function (resolve) { resolve(required(cat)) }); },\n            whenConsent: function (cat, f) { if (required(cat)) { f(); } },\n        };\n    })();\n\n//]]></script>\n    \n<script>//<![CDATA[\n\n    var Stash = {"common":{"companyuserid":null,"csrf_token":"b9765f5ebd94e9fe44d74db1131fbef1d13e9feb","lang":"da","lang_available":["da","en"],"lang_native":"da","site":"jobdk","sitename":"Jobindex","sitename_genitive":"Jobindex\'","userid":null},"cookie_consent":{"categories":[{"key":"necessary","required":true,"title":"Nødvendige"},{"key":"statistics","required":false,"title":"Statistik"},{"key":"marketing","required":false,"title":"Markedsføring"}],"cookieOptions":{"domain":".jobindex.dk","maxAge":31536000,"name":"jix-consent","path":"\\/","secure":true},"currentVersion":1,"latestTermsVersion":203,"options":{"enableAutoOpen":true,"enableBox":true,"modalCss":[],"sandbox":false},"urls":{"logConsent":"\\/api\\/cookie-consent\\/v1\\/log"}},"jobagent\\/popup":{"formSelector":"#jobagent_form"},"jobsearch":{"form_options":{"api":{" ...
#  '<!DOCTYPE html>\n<html lang="da-DK">\n    \n<head>\n    <title>Ledige job, side 5 ud af 732 | Jobindex</title>\n    <meta content="IE=edge" http-equiv="X-UA-Compatible">\n    <meta charset="UTF-8">\n\n    \n        <link rel="icon" href="/favicon.ico" sizes="any">\n        <link rel="icon" href="/icon.svg" type="image/svg+xml">\n        <link rel="apple-touch-icon" href="/apple-touch-icon.png">\n    <link rel="manifest" href="/manifest.webmanifest">\n\n    <link href="/res/bootstrap-multiselect/dist/css/bootstrap-multiselect.css?h=6a6b68a249811e054fa8d759452816a9248c0748" rel="stylesheet"><link href="/res/select2/dist/css/select2.min.css?h=a170ecdd58f00519741ed4b63abc064ef35db1a9" rel="stylesheet"><link href="/res/bootstrap-datepicker/dist/css/bootstrap-datepicker3.standalone.min.css?h=f02cbfe4614ade97b3e5823be92702ae7bd445cd" rel="stylesheet"><link href="/res/maplibre-gl/dist/maplibre-gl.css?h=0b7aecaa763c9b1b2cb3b2f908ae2456699cad67" rel="stylesheet"><link href="/res/font-awesome/css/font-awesome.css?h=ee906a8196d0fbd581c27a9d5615db4c250860f2" rel="stylesheet"><link href="/css/_scss/fonts/roboto.5ea080079207ad7dd581.css" rel="stylesheet"><link href="/css/_scss/fonts/frank_ruhl_libre.15701488e7249b2dbfe5.css" rel="stylesheet"><link href="/css/_scss/themes/jobindex.cf10eab771fcc3e82823.css" rel="stylesheet">\n\n    <meta content="text/html; charset=UTF-8" http-equiv="content-type"><meta content="da-DK" http-equiv="content-language">\n    <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"><meta content="none" name="msapplication-config"><meta content="#b41018" name="theme-color">\n\n\n\n    <script type="application/ld+json">\n        {"@context":"https:\\/\\/schema.org","@type":"WebSite","name":"Jobindex","url":"https:\\/\\/www.jobindex.dk\\/"}\n    </script>\n    <meta content="Jobindex" property="og:site_name">\n    \n    <meta content="https://www.jobindex.dk/jobsoegning?page=5" property="og:url">\n    \n    \n<link href="https://www.jobindex.dk/jobsoegning?page=5" rel="canonical">\n<link href="https://www.jobindex.dk/jobsoegning?page=5" hreflang="da" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?page=5&amp;lang=en" hreflang="en" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?page=5" hreflang="x-default" rel="alternate">\n\n    <link href="/jobsoegning.rss" rel="alternate nofollow" title="Alle ledige job" type="application/rss+xml">\n\n    <script>//<![CDATA[\n\n    window.JIX = window.JIX || {};\n    (function () {\n        \'use strict\';\n        if (window.JIX.CookieConsent) {\n            return;\n        }\n        \n        function required(cat) {\n            return ["necessary"].indexOf(cat) >= 0;\n        }\n        // In case an ad blocker rejects our real implementation, we\'ll just do nothing and leave people alone.\n        window.JIX.CookieConsent = {\n            hasConsent: function (cat) { return new Promise(function (resolve) { resolve(required(cat)) }); },\n            whenConsent: function (cat, f) { if (required(cat)) { f(); } },\n        };\n    })();\n\n//]]></script>\n    \n<script>//<![CDATA[\n\n    var Stash = {"common":{"companyuserid":null,"csrf_token":"7d3d13324e4363e87295c205407f36aa4aeb12b5","lang":"da","lang_available":["da","en"],"lang_native":"da","site":"jobdk","sitename":"Jobindex","sitename_genitive":"Jobindex\'","userid":null},"cookie_consent":{"categories":[{"key":"necessary","required":true,"title":"Nødvendige"},{"key":"statistics","required":false,"title":"Statistik"},{"key":"marketing","required":false,"title":"Markedsføring"}],"cookieOptions":{"domain":".jobindex.dk","maxAge":31536000,"name":"jix-consent","path":"\\/","secure":true},"currentVersion":1,"latestTermsVersion":203,"options":{"enableAutoOpen":true,"enableBox":true,"modalCss":[],"sandbox":false},"urls":{"logConsent":"\\/api\\/cookie-consent\\/v1\\/log"}},"jobagent\\/popup":{"formSelector":"#jobagent_form"},"jobsearch":{"form_options":{"api":{" ...

# %% [markdown]
# #### It is good practice to limit the rate of your calls to the website
# You can do that with the function `time.sleep()`

# %%
list_htmls = []
for url in tqdm.tqdm(links): #Track the time left before completing the loop
    response = requests.get(url)
    html = response.text
    list_htmls.append(html)
    time.sleep(0.5) #Sleep for 0.5 seconds
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:07<00:00,  1.56s/it]

# %% [markdown]
# # Video 6.2: Logging and handling exceptions

# %% [markdown]
# ## Logging
# Logging your web scraping activity is crucial to ensuring and demonstrating data quality. It helps you:
# - to document the data you extract
# - to understand the reasons behind any unexpected stops of your web scraper

# %% [markdown]
# ### Minimum essentials to log
# - *Time* of the scrape
# - The *status code* of the request response
#     - If succesful, the status code is normally *200*
#     - A common error is *404*: "*Page not found*"
# - The *length* of the output
#     - To indicate whether there may be a mistake
#     - In our case the output is usually some HTML code
# - The *path* to the output file
#     - What did we actually scrape?

# %% [markdown]
# #### Here is a simple logging function that you can use:

# %%
# Define the log function to gather the log information
def log(response,logfile,output_path=os.getcwd()):
    # Open or create the csv file
    if os.path.isfile(logfile): #If the log file exists, open it and allow for changes     
        log = open(logfile,'a')
    else: #If the log file does not exist, create it and make headers for the log variables
        log = open(logfile,'w')
        header = ['timestamp','status_code','length','output_file']
        log.write(';'.join(header) + "\n") #Make the headers and jump to new line
        
    # Gather log information
    status_code = response.status_code #Status code from the request result
    timestamp = time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(time.time())) #Local time
    length = len(response.text) #Length of the HTML-string
    
    # Open the log file and append the gathered log information
    with open(logfile,'a') as log:
        log.write(f'{timestamp};{status_code};{length};{output_path}' + "\n") #Append the information and jump to new line

# %% [markdown]
# #### Apply to web scrape:

# %%
list_htmls = []
logfile = 'log.csv'
for url in tqdm.tqdm(links):
    response = requests.get(url)
    html = response.text
    list_htmls.append(html)
    time.sleep(0.5)
    log(response,logfile)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:06<00:00,  1.33s/it]

# %% [markdown]
# ## Handling exceptions
# When you web scrape you will encounter unexpected errors or crashes.
# Some common errors may be:
# - The URL does not exist
# - The connection to the internet stops
#
# How can we mitigate such problems?
# - The `Try/Except` block in python can help us
#     - If the computer encounter an error then it will execute the except code block instead

# %%
list_htmls = []
for url in tqdm.tqdm(links):
    try:
        response = requests.get(url)
    except Exception as e:
        print(url) #Print url
        print(e) #Print error
        with open("list_htmls", "w") as l: #Save the list_htmls as a json file to retrieve at another time
            json.dump(list_htmls, l)
        continue #Continue to next iteration of the loop
    html = response.text
    list_htmls.append(html)
    time.sleep(0.5) #Sleep for 0.5 seconds
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:05<00:00,  1.10s/it]

# %% [markdown]
# # Video 6.3: The network panel

# %% [markdown]
# ## Background
# Many webpages are built dynamically
# - Each time you open up the webpage, it sends some **requests** to the server to retrieve the data that you see on the webpage

# %% [markdown]
# We can find these requests and use them!
# - We can then send them directly to the server
# - And then extract the data *before* it is written into the HTML
#     - Much more preferable: The data usually comes in a structured JSON format
#     - Makes it easy to use the data right away

# %% [markdown]
# ## The network panel in Chrome Developer Tools
# Use the **network panel** in the Chrome Developer Tools
# - The network panel monitors all uploads and downloads to and from the webpage
# - I.e., the network panel also monitors requests about data we are interested in

# %% [markdown]
# ### The network panel: [www.boligsiden.dk](https://www.boligsiden.dk/tilsalg)
# <img src="https://drive.google.com/thumbnail?id=1vGk2b1jxH1LU642-YWo1QgR3Q5vz2rQe&sz=w1000">

# %% [markdown]
# ### Which request is the one?
# 1. We want to locate an XHR ([XMLHttpRequest](https://en.wikipedia.org/wiki/XMLHttpRequest)). The XHRs transfer data between the server and the webpage
#     - Pick "*Fetch/XHR*"
# 2. Which XHR carries the information about the properties?
#     - We need to look through them all --> You can get a preview of the JSON file in "*Preview*"
# 3. When we have found the right XHR, we need to find the request URL
#     - Go to "*Headers*". Here you see the request URL

# %% [markdown]
# ### The steps:

# %% [markdown]
# #### Send the request to the server and get the data

# %%
response = requests.get('https://api.prod.bs-aws-stage.com/search/cases?addressTypes=villa%2Ccondo%2Cterraced+house%2Choliday+house%2Ccooperative%2Cfarm%2Chobby+farm%2Cfull+year+plot%2Cvilla+apartment%2Choliday+plot&per_page=50&page=1&highlighted=true&sortAscending=true&sortBy=timeOnMarket')

# %% [markdown]
# #### Convert the data to a JSON format in Python

# %%
result = response.json()

# %% [markdown]
# #### The JSON file consists of two different key-value pairs ("cases" and "links").
# #### We are only interested in the information about properties which are stored in the "cases" key-value pair

# %%
result_properties = result['cases']

# %% [markdown]
# #### Now we can easily convert the JSON file to a pandas DataFrame

# %%
data = pd.DataFrame(result_properties)

# %%
data
# Out:
#                                                _links  \
# 0   {'self': {'href': '/cases/1d14213d-5ec2-40b5-9...
# 1   {'self': {'href': '/cases/03f4f445-e3a6-49de-a...
# 2   {'self': {'href': '/cases/4422cd66-302a-4acb-8...
# 3   {'self': {'href': '/cases/3f8df5c6-78d8-42df-a...
# 4   {'self': {'href': '/cases/6b4f76af-9be5-4d01-b...
# 5   {'self': {'href': '/cases/283d6358-3046-439b-b...
# 6   {'self': {'href': '/cases/7f862a0d-e76e-4526-a...
# 7   {'self': {'href': '/cases/8fc69a26-c0a3-43a5-a...
# 8   {'self': {'href': '/cases/cd011c2c-ab3e-40e0-a...
# 9   {'self': {'href': '/cases/3c4e85a8-e599-4a5b-9...
# 10  {'self': {'href': '/cases/6b8bf440-8b91-42fd-8...
# 11  {'self': {'href': '/cases/2ec53367-305b-4472-9...
# 12  {'self': {'href': '/cases/aec7153f-4413-43d4-a...
# 13  {'self': {'href': '/cases/74510804-2e1e-4ba1-9...
# 14  {'self': {'href': '/cases/3c6478eb-0670-4e7b-8...
# 15  {'self': {'href': '/cases/1d190e76-f13b-4269-8...
# 16  {'self': {'href': '/cases/6e31a4fc-68f3-44ee-a...
# 17  {'self': {'href': '/cases/c521cf35-76af-4d7c-9...
# 18  {'self': {'href': '/cases/e4a7a283-de03-4319-b...
# 19  {'self': {'href': '/cases/27709add-5b72-478a-b...
# 20  {'self': {'href': '/cases/fb7101d5-2239-4530-a...
# 21  {'self': {'href': '/cases/dcb6b513-7513-4ac7-8...
# 22  {'self': {'href': '/cases/e426221f-4e97-4104-b...
# 23  {'self': {'href': '/cases/604670f4-d5ab-4ddf-8...
# 24  {'self': {'href': '/cases/27a96ba4-fd1c-4958-b...
# 25  {'self': {'href': '/cases/71ec8094-9bf7-40ec-a...
# 26  {'self': {'href': '/cases/3bb174f3-ced6-41b8-a...
# 27  {'self': {'href': '/cases/9ca8d12a-9168-4710-9...
# 28  {'self': {'href': '/cases/364d0ff1-46ba-40e5-b...
# 29  {'self': {'href': '/cases/977b1cc3-78b5-4330-a...
# 30  {'self': {'href': '/cases/496c069d-c1c1-4c8c-9...
# 31  {'self': {'href': '/cases/ebf0511f-0dc7-41d6-b...
# 32  {'self': {'href': '/cases/b7624001-ff99-494e-9...
# 33  {'self': {'href': '/cases/d502615b-7ce9-4651-b...
# 34  {'self': {'href': '/cases/669cf268-218d-496c-9...
# 35  {'self': {'href': '/cases/0c62b821-e418-415a-b...
# 36  {'self': {'href': '/cases/26e47137-5446-441f-9...
# 37  {'self': {'href': '/cases/caea1f6f-8920-4285-a...
# 38  {'self': {'href': '/cases/eecc692e-7478-4f9f-b...
# 39  {'self': {'href': '/cases/85834cbb-f6cb-4421-9...
# 40  {'self': {'href': '/cases/28060c7c-49d2-4459-9...
# 41  {'self': {'href': '/cases/c9ca3be1-6fef-4fd5-9...
# 42  {'self': {'href': '/cases/d9c247c2-f3bd-4ddf-9...
# 43  {'self': {'href': '/cases/cce4cef2-6e87-4593-9...
# 44  {'self': {'href': '/cases/53e5068c-d97a-43c9-8...
# 45  {'self': {'href': '/cases/e3efa180-4c35-49b0-a...
# 46  {'self': {'href': '/cases/d343f39e-e0aa-46c0-b...
# 47  {'self': {'href': '/cases/62997cc1-b41e-4c80-b...
# 48  {'self': {'href': '/cases/02b498ee-edff-40ba-b...
# 49  {'self': {'href': '/cases/e47dd537-f07c-40ea-9...
#
#                                               address     addressType  \
# 0   {'_links': {'self': {'href': '/addresses/0a3f5...           condo
# 1   {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 2   {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 3   {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 4   {'_links': {'self': {'href': '/addresses/16d19...           villa
# 5   {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 6   {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 7   {'_links': {'self': {'href': '/addresses/0a3f5...           condo
# 8   {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 9   {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 10  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 11  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 12  {'_links': {'self': {'href': '/addresses/0a3f5...   holiday house
# 13  {'_links': {'self': {'href': '/addresses/0a3f5...  terraced house
# 14  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 15  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 16  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 17  {'_links': {'self': {'href': '/addresses/0a3f5...           condo
# 18  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 19  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 20  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 21  {'_links': {'self': {'href': '/addresses/0a3f5...           condo
# 22  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 23  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 24  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 25  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 26  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 27  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 28  {'_links': {'self': {'href': '/addresses/0a3f5...  terraced house
# 29  {'_links': {'self': {'href': '/addresses/3ab03...           condo
# 30  {'_links': {'self': {'href': '/addresses/0a3f5...           condo
# 31  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 32  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 33  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 34  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 35  {'_links': {'self': {'href': '/addresses/0a3f5...   holiday house
# 36  {'_links': {'self': {'href': '/addresses/0e70c...  terraced house
# 37  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 38  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 39  {'_links': {'self': {'href': '/addresses/0a3f5...   holiday house
# 40  {'_links': {'self': {'href': '/addresses/a1e8c...           villa
# 41  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 42  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 43  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 44  {'_links': {'self': {'href': '/addresses/48b63...  terraced house
# 45  {'_links': {'self': {'href': '/addresses/0a3f5...   holiday house
# 46  {'_links': {'self': {'href': '/addresses/0a3f5...  terraced house
# 47  {'_links': {'self': {'href': '/addresses/0a3f5...  terraced house
# 48  {'_links': {'self': {'href': '/addresses/d0cb2...           condo
# 49  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
#
#                                   caseID  \
# 0   1d14213d-5ec2-40b5-9ffe-21819e264f46
# 1   03f4f445-e3a6-49de-a5d2-1b052801b92c
# 2   4422cd66-302a-4acb-89e1-bebfbd0fde9d
# 3   3f8df5c6-78d8-42df-a5dd-e4084c7cc107
# 4   6b4f76af-9be5-4d01-b57b-8cea9e3504b8
# 5   283d6358-3046-439b-b465-662e202d7af0
# 6   7f862a0d-e76e-4526-aa5b-1726b3e36ffc
# 7   8fc69a26-c0a3-43a5-a9d3-5d50acc67ba9
# 8   cd011c2c-ab3e-40e0-a040-077572742a8b
# 9   3c4e85a8-e599-4a5b-9c76-e89da078a248
# 10  6b8bf440-8b91-42fd-8e74-0705677ddd6e
# 11  2ec53367-305b-4472-9a53-3dfad7771ca9
# 12  aec7153f-4413-43d4-a487-d58393851eef
# 13  74510804-2e1e-4ba1-9732-29228a9ef66a
# 14  3c6478eb-0670-4e7b-81d9-6095aca73a32
# 15  1d190e76-f13b-4269-810b-407e80e9b308
# 16  6e31a4fc-68f3-44ee-a39b-b934856fc1f2
# 17  c521cf35-76af-4d7c-9797-1a5dab853c10
# 18  e4a7a283-de03-4319-b441-f25dd2453eff
# 19  27709add-5b72-478a-b8f5-3152a813e6c4
# 20  fb7101d5-2239-4530-a507-3516590a3a13
# 21  dcb6b513-7513-4ac7-826d-f16c33e6b8ff
# 22  e426221f-4e97-4104-b15f-e4d4955cfe8a
# 23  604670f4-d5ab-4ddf-8400-4fc657cd582c
# 24  27a96ba4-fd1c-4958-b184-22ec4912e3b1
# 25  71ec8094-9bf7-40ec-a69e-d87bf76a4f03
# 26  3bb174f3-ced6-41b8-a3ad-61d5f775d793
# 27  9ca8d12a-9168-4710-9d3e-146e8f8fc248
# 28  364d0ff1-46ba-40e5-bbf0-c21616d3ff32
# 29  977b1cc3-78b5-4330-a205-1437666a124e
# 30  496c069d-c1c1-4c8c-9e70-11bddd7020a2
# 31  ebf0511f-0dc7-41d6-b50a-fa99efedfc89
# 32  b7624001-ff99-494e-9b6f-7450e357ef9b
# 33  d502615b-7ce9-4651-b3f5-c8a515e8aed2
# 34  669cf268-218d-496c-91e6-ff61b7587740
# 35  0c62b821-e418-415a-bdc5-c2c63af6481e
# 36  26e47137-5446-441f-98fa-80c25307d344
# 37  caea1f6f-8920-4285-ad90-c7f87362e0a7
# 38  eecc692e-7478-4f9f-b8c5-31b03af8bf4b
# 39  85834cbb-f6cb-4421-9320-92998cab937e
# 40  28060c7c-49d2-4459-901c-1af06ce93cab
# 41  c9ca3be1-6fef-4fd5-9a75-0342ce423c58
# 42  d9c247c2-f3bd-4ddf-909e-98e7837dcbb7
# 43  cce4cef2-6e87-4593-956b-84bbf073ada6
# 44  53e5068c-d97a-43c9-8bae-de79fe5519fa
# 45  e3efa180-4c35-49b0-a5cf-46012d653b7d
# 46  d343f39e-e0aa-46c0-b4ad-07c856a3f0d8
# 47  62997cc1-b41e-4c80-b574-857721b348d0
# 48  02b498ee-edff-40ba-b2b0-54781f3769af
# 49  e47dd537-f07c-40ea-9b5f-699d88ac7a77
#
#                                               caseUrl  \
# 0   https://www.danbolig.dk?propertyid=0140003604&...
# 1   https://www.danbolig.dk?propertyid=0140003442&...
# 2   https://www.nybolig.dk/services/redirect/case/...
# 3   https://www.danbolig.dk?propertyid=0140003507&...
# 4   https://www.nybolig.dk/services/redirect/case/...
# 5   https://www.realmaeglerne.dk/301-redirect/?mgl...
# 6   https://www.nybolig.dk/services/redirect/case/...
# 7   https://www.lm-bolig.dk/sag.aspx?mgl=2245&sags...
# 8   https://www.danbolig.dk?propertyid=2840000859&...
# 9   https://www.danbolig.dk?propertyid=0140003420&...
# 10  https://www.nybolig.dk/services/redirect/case/...
# 11  https://www.lm-bolig.dk/sag.aspx?mgl=2245&sags...
# 12  https://www.danbolig.dk?propertyid=2830000408&...
# 13  https://www.lm-bolig.dk/sag.aspx?mgl=2245&sags...
# 14  https://www.kjeldskov.dk/templates/kjeldskov/i...
# 15  https://www.danbolig.dk?propertyid=0140003501&...
# 16  https://www.danbolig.dk?propertyid=0140003496&...
# 17  https://www.danbolig.dk?propertyid=0140003460&...
# 18  https://www.danbolig.dk?propertyid=0140003455&...
# 19  https://www.danbolig.dk?propertyid=0140003566&...
# 20  https://www.danbolig.dk?propertyid=1900001310&...
# 21  https://www.danbolig.dk?propertyid=0350001148&...
# 22  https://www.danbolig.dk?propertyid=1900001338&...
# 23  https://www.danbolig.dk?propertyid=1770000865&...
# 24  https://www.danbolig.dk?propertyid=0140003520&...
# 25  https://www.danbolig.dk?propertyid=0350001123&...
# 26               https://etnythjem.dk/sag/27290000171
# 27  https://www.danbolig.dk?propertyid=1900001306&...
# 28            https://www.edc.dk/sag/?sagsnr=54703612
# 29  https://www.danbolig.dk?propertyid=2720000598&...
# 30                     https://home.dk/sag/7190002520
# 31            https://www.edc.dk/sag/?sagsnr=56803421
# 32                     https://home.dk/sag/7230000215
# 33  https://www.danbolig.dk?propertyid=3120000627&...
# 34  https://www.danbolig.dk?propertyid=3120000614&...
# 35            https://www.edc.dk/sag/?sagsnr=71105728
# 36  http://www.wernerboliger.dk/sag.aspx?mgl=2804&...
# 37  https://www.realmaeglerne.dk/301-redirect/?mgl...
# 38                     https://home.dk/sag/6210001028
# 39            https://www.edc.dk/sag/?sagsnr=67301753
# 40            https://www.edc.dk/sag/?sagsnr=52704510
# 41  https://www.danbolig.dk?propertyid=0140003142&...
# 42  https://www.danbolig.dk?propertyid=0760000930&...
# 43  https://www.estate.dk/services/redirect/case/N...
# 44  https://www.nybolig.dk/services/redirect/case/...
# 45            https://www.edc.dk/sag/?sagsnr=67900769
# 46  https://www.danbolig.dk?propertyid=2730000494&...
# 47                     https://home.dk/sag/7190002565
# 48  https://www.danbolig.dk?propertyid=2720000625&...
# 49  https://www.estate.dk/services/redirect/case/N...
#
#                                           coordinates  daysOnMarket  \
# 0   {'lat': 55.716606, 'lon': 11.717513, 'type': '...             1
# 1   {'lat': 55.61825, 'lon': 11.5965805, 'type': '...             1
# 2   {'lat': 55.279335, 'lon': 11.796701, 'type': '...             1
# 3   {'lat': 55.647564, 'lon': 11.596645, 'type': '...             1
# 4   {'lat': 55.255337, 'lon': 11.881648, 'type': '...             1
# 5   {'lat': 55.11932, 'lon': 12.043173, 'type': 'E...             2
# 6   {'lat': 55.199356, 'lon': 11.762476, 'type': '...             3
# 7   {'lat': 55.4078, 'lon': 11.389755, 'type': 'EP...             3
# 8   {'lat': 55.39564, 'lon': 11.354792, 'type': 'E...             3
# 9   {'lat': 55.715225, 'lon': 11.735379, 'type': '...             3
# 10  {'lat': 55.22934, 'lon': 11.737182, 'type': 'E...             3
# 11  {'lat': 55.526466, 'lon': 12.204029, 'type': '...             3
# 12  {'lat': 55.506348, 'lon': 11.167545, 'type': '...             3
# 13  {'lat': 55.715992, 'lon': 12.446004, 'type': '...             3
# 14  {'lat': 55.615753, 'lon': 12.386745, 'type': '...             4
# 15  {'lat': 55.541992, 'lon': 11.711653, 'type': '...             5
# 16  {'lat': 55.708416, 'lon': 11.705456, 'type': '...             5
# 17  {'lat': 55.713203, 'lon': 11.726427, 'type': '...             6
# 18  {'lat': 55.648125, 'lon': 11.500338, 'type': '...             6
# 19  {'lat': 55.685207, 'lon': 11.7029915, 'type': ...             6
# 20  {'lat': 55.56023, 'lon': 12.259567, 'type': 'E...             6
# 21  {'lat': 55.83964, 'lon': 12.414103, 'type': 'E...             6
# 22  {'lat': 55.57414, 'lon': 12.267656, 'type': 'E...             6
# 23  {'lat': 55.5335, 'lon': 12.227524, 'type': 'EP...             6
# 24  {'lat': 55.61518, 'lon': 11.765239, 'type': 'E...             6
# 25  {'lat': 55.83424, 'lon': 12.432059, 'type': 'E...             6
# 26  {'lat': 55.49881, 'lon': 12.191597, 'type': 'E...             6
# 27  {'lat': 55.60392, 'lon': 12.318327, 'type': 'E...             6
# 28  {'lat': 55.48677, 'lon': 10.254192, 'type': 'E...             7
# 29  {'lat': 55.675842, 'lon': 12.519407, 'type': '...             7
# 30  {'lat': 55.245014, 'lon': 9.479565, 'type': 'E...             7
# 31  {'lat': 55.199192, 'lon': 10.155306, 'type': '...             7
# 32  {'lat': 55.19588, 'lon': 9.357194, 'type': 'EP...             7
# 33  {'lat': 56.988663, 'lon': 9.880827, 'type': 'E...             8
# 34  {'lat': 57.00745, 'lon': 9.820076, 'type': 'EP...             8
# 35  {'lat': 56.583347, 'lon': 8.139765, 'type': 'E...             8
# 36  {'lat': 55.355427, 'lon': 12.23197, 'type': 'E...             8
# 37  {'lat': 55.104397, 'lon': 10.215041, 'type': '...             8
# 38  {'lat': 56.332294, 'lon': 9.549428, 'type': 'E...             8
# 39  {'lat': 55.427082, 'lon': 8.381426, 'type': 'E...             9
# 40  {'lat': 55.418705, 'lon': 10.3637495, 'type': ...             9
# 41  {'lat': 55.735428, 'lon': 11.703574, 'type': '...             9
# 42  {'lat': 55.78963, 'lon': 12.273258, 'type': 'E...             9
# 43  {'lat': 55.608627, 'lon': 12.579034, 'type': '...             9
# 44  {'lat': 55.82854, 'lon': 12.339051, 'type': 'E...             9
# 45  {'lat': 55.153683, 'lon': 8.526047, 'type': 'E...             9
# 46  {'lat': 56.17692, 'lon': 10.192982, 'type': 'E...             9
# 47  {'lat': 55.24233, 'lon': 9.483707, 'type': 'EP...             9
# 48  {'lat': 55.66447, 'lon': 12.5368595, 'type': '...             9
# 49  {'lat': 55.856163, 'lon': 12.428489, 'type': '...             9
#
#                                          defaultImage  \
# 0   {'imageSources': [{'size': {'height': 80, 'wid...
# 1   {'imageSources': [{'size': {'height': 80, 'wid...
# 2   {'imageSources': [{'size': {'height': 80, 'wid...
# 3   {'imageSources': [{'size': {'height': 80, 'wid...
# 4   {'imageSources': [{'size': {'height': 80, 'wid...
# 5   {'imageSources': [{'size': {'height': 80, 'wid...
# 6   {'imageSources': [{'size': {'height': 80, 'wid...
# 7   {'imageSources': [{'size': {'height': 80, 'wid...
# 8   {'imageSources': [{'size': {'height': 80, 'wid...
# 9   {'imageSources': [{'size': {'height': 80, 'wid...
# 10  {'imageSources': [{'size': {'height': 80, 'wid...
# 11  {'imageSources': [{'size': {'height': 80, 'wid...
# 12  {'imageSources': [{'size': {'height': 80, 'wid...
# 13  {'imageSources': [{'size': {'height': 80, 'wid...
# 14  {'imageSources': [{'size': {'height': 80, 'wid...
# 15  {'imageSources': [{'size': {'height': 80, 'wid...
# 16  {'imageSources': [{'size': {'height': 80, 'wid...
# 17  {'imageSources': [{'size': {'height': 80, 'wid...
# 18  {'imageSources': [{'size': {'height': 80, 'wid...
# 19  {'imageSources': [{'size': {'height': 80, 'wid...
# 20  {'imageSources': [{'size': {'height': 80, 'wid...
# 21  {'imageSources': [{'size': {'height': 80, 'wid...
# 22  {'imageSources': [{'size': {'height': 80, 'wid...
# 23  {'imageSources': [{'size': {'height': 80, 'wid...
# 24  {'imageSources': [{'size': {'height': 80, 'wid...
# 25  {'imageSources': [{'size': {'height': 80, 'wid...
# 26  {'imageSources': [{'size': {'height': 80, 'wid...
# 27  {'imageSources': [{'size': {'height': 80, 'wid...
# 28  {'imageSources': [{'size': {'height': 80, 'wid...
# 29  {'imageSources': [{'size': {'height': 80, 'wid...
# 30  {'imageSources': [{'size': {'height': 80, 'wid...
# 31  {'imageSources': [{'size': {'height': 80, 'wid...
# 32  {'imageSources': [{'size': {'height': 80, 'wid...
# 33  {'imageSources': [{'size': {'height': 80, 'wid...
# 34  {'imageSources': [{'size': {'height': 80, 'wid...
# 35  {'imageSources': [{'size': {'height': 80, 'wid...
# 36  {'imageSources': [{'size': {'height': 80, 'wid...
# 37  {'imageSources': [{'size': {'height': 80, 'wid...
# 38  {'imageSources': [{'size': {'height': 80, 'wid...
# 39  {'imageSources': [{'size': {'height': 80, 'wid...
# 40  {'imageSources': [{'size': {'height': 80, 'wid...
# 41  {'imageSources': [{'size': {'height': 80, 'wid...
# 42  {'imageSources': [{'size': {'height': 80, 'wid...
# 43  {'imageSources': [{'size': {'height': 80, 'wid...
# 44  {'imageSources': [{'size': {'height': 80, 'wid...
# 45  {'imageSources': [{'size': {'height': 80, 'wid...
# 46  {'imageSources': [{'size': {'height': 80, 'wid...
# 47  {'imageSources': [{'size': {'height': 80, 'wid...
# 48  {'imageSources': [{'size': {'height': 80, 'wid...
# 49  {'imageSources': [{'size': {'height': 80, 'wid...
#
#                                       descriptionBody  \
# 0   Centralt i Holbæk tæt på alle byens tilbud og ...
# 1   På trods af husets relativt unge alder er det ...
# 2   I fredelige, familievenlige omgivelser i Fensm...
# 3   Om det er muligheder eller naturoplevelser, du...
# 4   For enden af en stille, fredelig villavej i To...
# 5   På en meget central og fordelagtig beliggenhed...
# 6   I bunden af et lukket vænge dukker denne indby...
# 7   Stor ejerlejlighed med egen have og garage.Lej...
# 8   Velkommen til Astersvej 7 – en ejendom i særkl...
# 9   Svinget er en stille villavej, tæt på centrum ...
# 10  Det er forståeligt, at Digtervejskvarteret er ...
# 11  Gemt væk bag høje træer på hyggelig familieven...
# 12  Moderniseret sommerhus i attraktivt områdeVelk...
# 13  OMRÅDET:Huset er beliggende midt i det meget e...
# 14  På en særdeles hyggelig og familievenlig lukke...
# 15  Søger I efter dejlige rammer, hvor børnene kan...
# 16  Dette charmerende hus fra 1967 er bevaret i si...
# 17  I bor absolut centralt på denne adresse i Holb...
# 18  Glæden ved at bo i en stationsby er de jævnlig...
# 19  I udkanten af Holbæk ligger denne charmerende ...
# 20  Nyistandsat Villa i Ræveholm – Perfekt til den...
# 21  I en nydelig ejendom med en særdeles god belig...
# 22  For enden af en blind vej ligger denne indbyde...
# 23  På en eftertragtet strandsidevej i Solrød Stra...
# 24  Der er masser af indkøbsmuligheder og institut...
# 25  Drømmer du om at bo direkte til skov, har du h...
# 26  Velkommen til dette flotte hjem, som har genne...
# 27  Villaen på Stenrøjel 11 er klassisk med mange ...
# 28  Åbent hus med tilmeldingskrav 26/7 - klik på b...
# 29  I ALT 100 ETAGEMETER - HØJ, UGENERET STUELEJLI...
# 30  Utrolig velholdt og velindrettet ejerlejlighed...
# 31  Særdeles spændende ejendom der kan benyttes so...
# 32  Med en god beliggenhed centralt i Vedsted, fin...
# 33  Velkommen til Klokkevej 22 – en charmerende ej...
# 34  Flot villa med tilhørende værksted i Frejlev V...
# 35  Det er altid en fornøjelse at møde ejendomme, ...
# 36  Opdag denne perle af et halvt dobbelthus belig...
# 37  Står du og mangler en indflytningsklar villa i...
# 38  Drømmer du om at bo i fredelige, landlige omgi...
# 39  Her på en lille stikvej til Vindgaf, på en god...
# 40  Åbent hus med tilmeldingskrav 26/7 - klik på b...
# 41  I anden række til vandet på nordsiden af Holbæ...
# 42  Hampetoften 2 i Ganløse er en charmerende ejen...
# 43  Et hus til salg på Ballingvej!   Ja, det er op...
# 44  I det attraktive Kasernekvarter udbydes nu det...
# 45  Åbent hus med tilmeldingskrav 26/7 - klik på b...
# 46  Velkommen til dette charmerende rækkehus belig...
# 47  Bynært beliggende finder vi dette velholdte ræ...
# 48  Der er ikke en finger at sætte på denne tovære...
# 49  Det er med stor fornøjelse, at vi byder velkom...
#
#                                      descriptionTitle  ...  \
# 0               Flot, velindrettet lejlighed i Holbæk  ...
# 1   Enestående, stråtækt bindingsværkshus nær Undløse  ...
# 2   Indflytningsklar villa med flot kælder og skøn...  ...
# 3                   Byg om eller byg nyt nær Regstrup  ...
# 4   Lind & Risør-villa i Toksværd med en velholdt ...  ...
# 5                    GENNEMRENOVERET VILLA - CENTRALT  ...
# 6   Velbeliggende etplansvilla til familien i Næst...  ...
# 7         Stor ejerlejlighed med egen have og garage.  ...
# 8             Unik kvalitetsvilla centralt i Slagelse  ...
# 9      Superfint og velindrettet byhus tæt på fjorden  ...
# 10  Familievilla - på én af de bedste beliggenhede...  ...
# 11                                                NaN  ...
# 12         Moderniseret sommerhus i attraktivt område  ...
# 13                                                NaN  ...
# 14                    En hyldest til lyset og naturen  ...
# 15  Velindrettet etplansvilla i børnevenligt kvart...  ...
# 16  Charmerende og velholdt 1960’er-villa på en lu...  ...
# 17  Indflytningsklart rækkehus fra 2005 på en cent...  ...
# 18  Velholdt etplansvilla på stille vej i stations...  ...
# 19              Charmerende villa med skønt udemiljø.  ...
# 20  Nyistandsat Villa i Ræveholm – Perfekt til den...  ...
# 21  Hyggelig toværelses lejlighed centralt i Birke...  ...
# 22                Etplansvilla i Mosede med skøn have  ...
# 23  193 m2 liebhavervilla på strandsidevej i Solrø...  ...
# 24  Flot renoveret villa i den gode stationsby Tøl...  ...
# 25                         Direkte adgang til skov...  ...
# 26                      Flot istandsat bolig i Køge N  ...
# 27  Stor villa på 198 m2 med mange værelser og skø...  ...
# 28  Overskueligt etplansrækkehus til renovering ce...  ...
# 29                                                NaN  ...
# 30                                          Haderslev  ...
# 31  Fritids- eller helårshus (Flexbolig). Spændend...  ...
# 32                                            Vedsted  ...
# 33            Stor bolig med solceller i Dall Villaby  ...
# 34       Flot villa med tilhørende værksted i Frejlev  ...
# 35  Skønt fritidshus med fem værelser og udsigt ov...  ...
# 36  Drømmebolig for familien: Halvt dobbelthus med...  ...
# 37                 Super velholdt villa med skøn have  ...
# 38  Dejligt nedlagt landbrug med 1,1 ha. jord vele...  ...
# 39  Totalrenoveret, velbeliggende og hyggeligt som...  ...
# 40  Charmerende villa i Næsby med plads og potentiale  ...
# 41                     Velgjort villa med fjordudsigt  ...
# 42           Familievilla med have, garage og udestue  ...
# 43  Etplansvilla med gulvvarme overalt og privat s...  ...
# 44  Hyggeligt, velholdt og veldisponeret rækkehus ...  ...
# 45       Hyggeligt "Seest-hus" på en stor naturgrund.  ...
# 46          Charmende enderækkehus på Christiansbjerg  ...
# 47                                          Haderslev  ...
# 48  Hyggelig to værelses lige til at flytte ind i,...  ...
# 49      Klassisk 50’er villa i den helt rigtige stil!  ...
#
#                                          timeOnMarket totalClickCount  \
# 0   {'current': {'days': 1}, 'total': {'days': 84,...             281
# 1   {'current': {'days': 1}, 'total': {'days': 1, ...             149
# 2   {'current': {'days': 1}, 'total': {'days': 1, ...             442
# 3   {'current': {'days': 1}, 'total': {'days': 1, ...             231
# 4   {'current': {'days': 1}, 'total': {'days': 1, ...             187
# 5   {'current': {'days': 2}, 'total': {'days': 2, ...             229
# 6   {'current': {'days': 3}, 'total': {'days': 3, ...             823
# 7   {'current': {'days': 3}, 'total': {'days': 3, ...             316
# 8   {'current': {'days': 3}, 'total': {'days': 3, ...             836
# 9   {'current': {'days': 3}, 'total': {'days': 3, ...             545
# 10  {'current': {'days': 3}, 'total': {'days': 3, ...             860
# 11  {'current': {'days': 3}, 'total': {'days': 3, ...             425
# 12  {'current': {'days': 3}, 'total': {'days': 3, ...             182
# 13  {'current': {'days': 3}, 'total': {'days': 3, ...             391
# 14  {'current': {'days': 4}, 'total': {'days': 4, ...             590
# 15  {'current': {'days': 5}, 'total': {'days': 5, ...             244
# 16  {'current': {'days': 5}, 'total': {'days': 5, ...             493
# 17  {'current': {'days': 6}, 'total': {'days': 6, ...             812
# 18  {'current': {'days': 6}, 'total': {'days': 6, ...             224
# 19  {'current': {'days': 6}, 'total': {'days': 273...             601
# 20  {'current': {'days': 6}, 'total': {'days': 6, ...             319
# 21  {'current': {'days': 6}, 'total': {'days': 6, ...             100
# 22  {'current': {'days': 6}, 'total': {'days': 6, ...             171
# 23  {'current': {'days': 6}, 'total': {'days': 6, ...             661
# 24  {'current': {'days': 6}, 'total': {'days': 198...             298
# 25  {'current': {'days': 6}, 'total': {'days': 274...             307
# 26  {'current': {'days': 6}, 'total': {'days': 6, ...             611
# 27  {'current': {'days': 6}, 'total': {'days': 6, ...             110
# 28  {'current': {'days': 7}, 'total': {'days': 7, ...             186
# 29  {'current': {'days': 7}, 'total': {'days': 7, ...             634
# 30  {'current': {'days': 7}, 'total': {'days': 308...             232
# 31  {'current': {'days': 7}, 'total': {'days': 7, ...             355
# 32  {'current': {'days': 7}, 'total': {'days': 7, ...             224
# 33  {'current': {'days': 8}, 'total': {'days': 8, ...             284
# 34  {'current': {'days': 8}, 'total': {'days': 8, ...             662
# 35  {'current': {'days': 8}, 'total': {'days': 8, ...             739
# 36  {'current': {'days': 8}, 'total': {'days': 8, ...             315
# 37  {'current': {'days': 8}, 'total': {'days': 8, ...             193
# 38  {'current': {'days': 8}, 'total': {'days': 8, ...             171
# 39  {'current': {'days': 9}, 'total': {'days': 9, ...             579
# 40                           {'current': {'days': 9}}             721
# 41  {'current': {'days': 9}, 'total': {'days': 9, ...             605
# 42  {'current': {'days': 9}, 'total': {'days': 9, ...             402
# 43  {'current': {'days': 9}, 'total': {'days': 9, ...             366
# 44  {'current': {'days': 9}, 'total': {'days': 9, ...             379
# 45  {'current': {'days': 9}, 'total': {'days': 9, ...             983
# 46  {'current': {'days': 9}, 'total': {'days': 9, ...             608
# 47  {'current': {'days': 9}, 'total': {'days': 9, ...             434
# 48  {'current': {'days': 9}, 'total': {'days': 9, ...             625
# 49  {'current': {'days': 9}, 'total': {'days': 114...             591
#
#     totalFavourites     utilitiesConnectionFee  yearBuilt  lotArea  \
# 0                 0  {'includedInPrice': None}       1949      NaN
# 1                 1  {'includedInPrice': None}       1827   4432.0
# 2                 1  {'includedInPrice': None}       1965    800.0
# 3                 1  {'includedInPrice': None}       1927   1009.0
# 4                 0  {'includedInPrice': None}       2007    888.0
# 5                 1  {'includedInPrice': None}       1962    925.0
# 6                 4  {'includedInPrice': None}       1972    712.0
# 7                 1  {'includedInPrice': None}       1971      NaN
# 8                 3  {'includedInPrice': None}       1953    655.0
# 9                 1  {'includedInPrice': None}       1939    400.0
# 10                4  {'includedInPrice': None}       1975    810.0
# 11                3  {'includedInPrice': None}       1974   1290.0
# 12                7  {'includedInPrice': None}       1967   1288.0
# 13                5  {'includedInPrice': None}       1953    734.0
# 14                3  {'includedInPrice': None}       1974    604.0
# 15                4  {'includedInPrice': None}       1966    627.0
# 16                3  {'includedInPrice': None}       1967    723.0
# 17                8  {'includedInPrice': None}       2005      NaN
# 18                2  {'includedInPrice': None}       1969   1150.0
# 19                5  {'includedInPrice': None}       1935    960.0
# 20                1  {'includedInPrice': None}       1973   1145.0
# 21                0  {'includedInPrice': None}       1960      NaN
# 22                4  {'includedInPrice': None}       1975   1042.0
# 23                4  {'includedInPrice': None}       2015    788.0
# 24                6  {'includedInPrice': None}       1973    754.0
# 25                2  {'includedInPrice': None}       1981   1182.0
# 26                3  {'includedInPrice': None}       1968    800.0
# 27                2  {'includedInPrice': None}       1966    771.0
# 28                2  {'includedInPrice': None}       1982    272.0
# 29                7  {'includedInPrice': None}       1883      NaN
# 30                0  {'includedInPrice': None}       1966      NaN
# 31                5  {'includedInPrice': None}       1990   1236.0
# 32                3  {'includedInPrice': None}       1948    751.0
# 33                1  {'includedInPrice': None}       1968    743.0
# 34                3  {'includedInPrice': None}       1933   1867.0
# 35               12  {'includedInPrice': None}       1989   2534.0
# 36                2  {'includedInPrice': None}       2019    844.0
# 37                2  {'includedInPrice': None}       1986    826.0
# 38                6  {'includedInPrice': None}       1852  11032.0
# 39                1  {'includedInPrice': None}       1984   2222.0
# 40                2  {'includedInPrice': None}       1939    880.0
# 41                4  {'includedInPrice': None}       1961    985.0
# 42                3  {'includedInPrice': None}       1968    700.0
# 43                6  {'includedInPrice': None}       1973    725.0
# 44                3  {'includedInPrice': None}       2012    128.0
# 45                6  {'includedInPrice': None}       1974   2531.0
# 46                8  {'includedInPrice': None}       1957    376.0
# 47                1  {'includedInPrice': None}       1963    266.0
# 48                7  {'includedInPrice': None}       2018      NaN
# 49                4  {'includedInPrice': None}       1952    768.0
#
#     weightedArea basementArea  \
# 0            NaN          NaN
# 1         200.60          NaN
# 2         164.30        106.0
# 3          79.00          NaN
# 4         172.90          NaN
# 5         175.15          NaN
# 6         164.00          NaN
# 7            NaN          NaN
# 8         228.65         76.0
# 9          86.20         61.0
# 10        193.50          NaN
# 11        176.00          NaN
# 12        136.75          NaN
# 13           NaN          NaN
# 14        132.00          NaN
# 15        163.25          NaN
# 16        156.95         89.0
# 17           NaN          NaN
# 18        194.70          NaN
# 19        157.20         61.0
# 20        154.70          NaN
# 21           NaN          NaN
# 22        122.30          NaN
# 23        197.80          NaN
# 24        137.50          NaN
# 25        150.80          NaN
# 26         88.25          NaN
# 27        196.95          NaN
# 28         80.30          NaN
# 29           NaN          NaN
# 30           NaN          NaN
# 31        172.05          NaN
# 32        145.05         92.0
# 33        179.10          NaN
# 34        223.45         42.0
# 35        102.20          NaN
# 36        128.10          NaN
# 37        138.90          NaN
# 38        182.00          NaN
# 39         78.70          NaN
# 40           NaN         98.0
# 41        278.30          NaN
# 42        162.20          NaN
# 43        157.70          NaN
# 44        125.00          NaN
# 45         62.00          NaN
# 46        118.10         54.0
# 47        120.60         44.0
# 48         63.00          NaN
# 49        175.25         53.0
#
#                                         nextOpenHouse  secondaryAddressType
# 0                                                 NaN                   NaN
# 1                                                 NaN                   NaN
# 2   {'date': '2024-07-31T14:00:00Z', 'duration': 3...                   NaN
# 3                                                 NaN                   NaN
# 4                                                 NaN                   NaN
# 5                                                 NaN                   NaN
# 6                                                 NaN                   NaN
# 7   {'date': '2024-07-28T13:00:00Z', 'duration': 3...                   NaN
# 8   {'date': '2024-08-04T09:00:00Z', 'duration': 9...                   NaN
# 9   {'date': '2024-07-28T09:00:00Z', 'duration': 3...                   NaN
# 10                                                NaN                   NaN
# 11  {'date': '2024-07-28T09:00:00Z', 'duration': 3...                   NaN
# 12                                                NaN                   NaN
# 13  {'date': '2024-07-28T10:30:00Z', 'duration': 3...                   NaN
# 14                                                NaN                   NaN
# 15                                                NaN                   NaN
# 16                                                NaN                   NaN
# 17  {'date': '2024-07-28T12:00:00Z', 'duration': 3...                   NaN
# 18  {'date': '2024-08-04T09:00:00Z', 'duration': 3...                   NaN
# 19  {'date': '2024-07-28T11:00:00Z', 'duration': 3...                   NaN
# 20                                                NaN                   NaN
# 21                                                NaN                   NaN
# 22                                                NaN                   NaN
# 23                                                NaN                   NaN
# 24  {'date': '2024-07-28T08:00:00Z', 'duration': 3...                   NaN
# 25  {'date': '2024-07-28T10:00:00Z', 'duration': 3...                   NaN
# 26                                                NaN                   NaN
# 27                                                NaN                   NaN
# 28  {'date': '2024-07-26T08:00:00Z', 'duration': 3...                   NaN
# 29  {'date': '2024-07-28T10:00:00Z', 'duration': 2...                   NaN
# 30                                                NaN                   NaN
# 31                                                NaN         holiday house
# 32                                                NaN                   NaN
# 33  {'date': '2024-07-30T08:00:00Z', 'duration': 3...                   NaN
# 34  {'date': '2024-07-30T08:00:00Z', 'duration': 3...                   NaN
# 35                                                NaN                   NaN
# 36                                                NaN                   NaN
# 37  {'date': '2024-07-25T08:00:00Z', 'duration': 3...                   NaN
# 38  {'date': '2024-08-10T08:00:00Z', 'duration': 2...                   NaN
# 39                                                NaN                   NaN
# 40  {'date': '2024-07-26T08:00:00Z', 'duration': 4...                   NaN
# 41  {'date': '2024-07-27T10:00:00Z', 'duration': 3...                   NaN
# 42                                                NaN                   NaN
# 43  {'date': '2024-07-28T11:35:00Z', 'duration': 2...                   NaN
# 44                                                NaN                   NaN
# 45  {'date': '2024-07-26T07:00:00Z', 'duration': 4...                   NaN
# 46                                                NaN                   NaN
# 47                                                NaN                   NaN
# 48  {'date': '2024-07-28T09:00:00Z', 'duration': 2...                   NaN
# 49                                                NaN                   NaN
#
# [50 rows x 42 columns]

# %% [markdown]
# ## And we have the data!
